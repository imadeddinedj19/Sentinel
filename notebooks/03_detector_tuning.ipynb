# %% [markdown]
# # Detector tuning
#
# - Sweep thresholds per detector
# - Validate against known manipulation events

# %%
import sys
sys.path.append("..")

import pandas as pd

from sentinel import config
