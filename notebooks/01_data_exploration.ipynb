# %% [markdown]
# # Data exploration
#
# - Pull a sample of klines and trades
# - Check gaps, duplicates and timestamp alignment

# %%
import sys
sys.path.append("..")

import pandas as pd

from sentinel import config
